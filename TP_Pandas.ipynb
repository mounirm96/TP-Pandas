# %%
import pandas as pd

# %%
CareerExtension = pd.read_csv("CareerExtension.csv")
SeaCareerSet = pd.read_csv("SeaCareerSet.csv")
Passenger = pd.read_excel("Passenger.xlsx")

# %%
SeaCareerSet.head(10)
# Out:
#    passenger_id                                               name     sex  \
# 0           334                    Vander Planke, Mr. Leo Edmondus    male
# 1           178                         Isham, Miss. Ann Elizabeth  female
# 2           320  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female
# 3           267                          Panula, Mr. Ernesti Arvid    male
# 4           489                      Somerton, Mr. Francis William    male
# 5           848                                 Markoff, Mr. Marin    male
# 6           451                              West, Mr. Edwy Arthur    male
# 7           526                                 Farrell, Mr. James    male
# 8           317                Kantor, Mrs. Sinai (Miriam Sternin)  female
# 9           179                                 Hale, Mr. Reginald    male
#
#     age     education      marital_status   relationship  class      fare  \
# ...

# %%
SeaCareerSet.tail(15)
# Out:
#      passenger_id                               name     sex   age  \
# 699           276  Andrews, Miss. Kornelia Theodosia  female  63.0
# 700           633          Stahelin-Maeglin, Dr. Max    male  32.0
# 701           795              Dantcheff, Mr. Ristiu    male  25.0
# 702           883       Dahlberg, Miss. Gerda Ulrika  female  22.0
# 703           172               Rice, Master. Arthur    male   4.0
# 704           423                 Zimmerman, Mr. Leo    male  29.0
# 705            91               Christmann, Mr. Emil    male  29.0
# 706           521              Perreault, Miss. Anne  female  30.0
# 707           173       Johnson, Miss. Eleanor Ileen  female   1.0
# 708           667        Butler, Mr. Reginald Fenton    male  25.0
# 709           689    Fischer, Mr. Eberhard Thelander    male  18.0
# 710           158                    Corn, Mr. Harry    male  30.0
# 711           641             Jensen, Mr. Hans Peder    male  20.0
# ...

# %%
SeaCareerSet.sample(10)
# Out:
#      passenger_id                                          name     sex   age  \
# 375           530                   Hocking, Mr. Richard George    male  23.0
# 27            244                 Maenpaa, Mr. Matti Alexanteri    male  22.0
# 634           560  de Messemaeker, Mrs. Guillaume Joseph (Emma)  female  36.0
# 703           172                          Rice, Master. Arthur    male   4.0
# 1             178                    Isham, Miss. Ann Elizabeth  female  50.0
# 98            865                        Gill, Mr. John William    male  24.0
# 310           501                              Calic, Mr. Petar    male  17.0
# 301           153                              Meo, Mr. Alfonzo    male  55.0
# 587            71                    Jenkin, Mr. Stephen Curnow    male  32.0
# 329           529                     Salonen, Mr. Johan Werner    male  39.0
#
#         education      marital_status   relationship  class     fare  sibsp  \
# ...

# %%
ech = SeaCareerSet.sample(10)
ech.to_csv("ech.csv", index=False)

# %% [markdown]
# ## Exo 2

# %%
SeaCareerSet.shape
# Out:
# (714, 21)

# %%
SeaCareerSet.describe()
# Out:
#        passenger_id         age       class        fare       sibsp  \
# count    714.000000  714.000000  714.000000  714.000000  714.000000
# mean     448.582633   29.690476    2.236695   34.694514    0.512605
# std      259.119524   14.517803    0.838250   52.918930    0.929783
# min        1.000000    1.000000    1.000000    0.000000    0.000000
# 25%      222.250000   20.000000    1.000000    8.050000    0.000000
# 50%      445.000000   28.000000    2.000000   15.741700    0.000000
# 75%      677.750000   38.000000    3.000000   33.375000    1.000000
# max      891.000000   80.000000    3.000000  512.329200    5.000000
#
#             parch  hours_per_week  capital_gain  capital_loss    survived
# count  714.000000      614.000000    714.000000    714.000000  714.000000
# mean     0.431373       39.744300    595.250700     67.107843    0.406162
# std      0.853289       12.353735   4375.747007    345.922761    0.491460
# ...

# %%
SeaCareerSet.describe(include= "object")
# Out:
#                                    name   sex education marital_status  \
# count                               714   714       614            614
# unique                              714     2        13              6
# top     Vander Planke, Mr. Leo Edmondus  male   HS-grad  Never-married
# freq                                  1   453       227            276
#
#        relationship     date_embarked embarked workclass occupation  \
# count           614               714      712       614        614
# unique            6                33        3         8         13
# top         Husband  10/04/1912 13:30        S   Private      Sales
# freq            197                47      554       443         80
#
#        native_country income
# count             614    714
# unique              2      3
# top     United-States  <=50K
# freq              600    504

# %%
SeaCareerSet['workclass'].unique()
# Out:
# array([nan, 'Local-gov', 'Private', 'Self-emp-not-inc', 'Self-emp-inc',
#        '?', 'State-gov', 'Federal-gov', 'Without-pay'], dtype=object)

# %%
#Catégorie "?" fait référence a quel catégorie et y a des valeurs "nan"

# %% [markdown]
# ## Exo 3

# %%
SeaCareerSet['education'].unique()
# Out:
# array([nan, 'Masters', 'Some-college', 'HS-grad', 'Bachelors', '11th',
#        'Prof-school', '10th', 'Assoc-voc', 'Assoc-acdm', '7th-8th',
#        'Doctorate', '12th', '9th'], dtype=object)

# %%
SeaCareerSet[SeaCareerSet['education'] == 'Masters']
# Out:
#      passenger_id                                               name     sex  \
# 0             334                    Vander Planke, Mr. Leo Edmondus    male
# 1             178                         Isham, Miss. Ann Elizabeth  female
# 2             320  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female
# 3             267                          Panula, Mr. Ernesti Arvid    male
# 4             489                      Somerton, Mr. Francis William    male
# ..            ...                                                ...     ...
# 709           689                    Fischer, Mr. Eberhard Thelander    male
# 710           158                                    Corn, Mr. Harry    male
# 711           641                             Jensen, Mr. Hans Peder    male
# 712           696                         Chapman, Mr. Charles Henry    male
# 713           652                                Doling, Miss. Elsie  female
#
# ...

# %%
SeaCareerSet[SeaCareerSet['age'] > 18]
# Out:
#      passenger_id                                               name     sex  \
# 1             178                         Isham, Miss. Ann Elizabeth  female
# 2             320  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female
# 4             489                      Somerton, Mr. Francis William    male
# 5             848                                 Markoff, Mr. Marin    male
# 6             451                              West, Mr. Edwy Arthur    male
# ..            ...                                                ...     ...
# 706           521                              Perreault, Miss. Anne  female
# 708           667                        Butler, Mr. Reginald Fenton    male
# 710           158                                    Corn, Mr. Harry    male
# 711           641                             Jensen, Mr. Hans Peder    male
# 712           696                         Chapman, Mr. Charles Henry    male
#
# ...

# %%
Single_p = SeaCareerSet[(SeaCareerSet['sibsp'] == 0) & (SeaCareerSet['parch'] == 0)]
Single_p
# Out:
#      passenger_id                             name     sex   age education  \
# 1             178       Isham, Miss. Ann Elizabeth  female  50.0   Masters
# 4             489    Somerton, Mr. Francis William    male  30.0   Masters
# 5             848               Markoff, Mr. Marin    male  35.0   Masters
# 7             526               Farrell, Mr. James    male  41.0   Masters
# 9             179               Hale, Mr. Reginald    male  30.0   Masters
# ..            ...                              ...     ...   ...       ...
# 708           667      Butler, Mr. Reginald Fenton    male  25.0   Masters
# 709           689  Fischer, Mr. Eberhard Thelander    male  18.0   Masters
# 710           158                  Corn, Mr. Harry    male  30.0   Masters
# 711           641           Jensen, Mr. Hans Peder    male  20.0   Masters
# 712           696       Chapman, Mr. Charles Henry    male  52.0   Masters
#
# ...

# %%
col_pass = ['passenger_id', 'name', 'sex', 'age', 'date_embarked']
infos_pass = Single_p[col_pass]
infos_pass
# Out:
#      passenger_id                             name     sex   age  \
# 1             178       Isham, Miss. Ann Elizabeth  female  50.0
# 4             489    Somerton, Mr. Francis William    male  30.0
# 5             848               Markoff, Mr. Marin    male  35.0
# 7             526               Farrell, Mr. James    male  41.0
# 9             179               Hale, Mr. Reginald    male  30.0
# ..            ...                              ...     ...   ...
# 708           667      Butler, Mr. Reginald Fenton    male  25.0
# 709           689  Fischer, Mr. Eberhard Thelander    male  18.0
# 710           158                  Corn, Mr. Harry    male  30.0
# 711           641           Jensen, Mr. Hans Peder    male  20.0
# 712           696       Chapman, Mr. Charles Henry    male  52.0
#
#         date_embarked
# 1    10/04/1912 19:50
# 4    10/04/1912 13:40
# 5    10/04/1912 18:45
# 7    11/04/1912 12:55
# 9    10/04/1912 13:20
# ..                ...
# ...

# %% [markdown]
# ## Exo 4

# %%
SeaCareerSet.isnull().sum()
# Out:
# passenger_id        0
# name                0
# sex                 0
# age                 0
# education           0
# marital_status    100
# relationship      100
# class               0
# fare                0
# sibsp               0
# parch               0
# date_embarked       0
# embarked            2
# workclass         100
# occupation        100
# hours_per_week    100
# capital_gain        0
# capital_loss        0
# native_country    100
# income              0
# survived            0
# dtype: int64

# %%
mean_hpw = SeaCareerSet['hours_per_week'].mean()
SeaCareerSet['hours_per_week'].fillna(mean_hpw, inplace=True)
SeaCareerSet['marital_status'].fillna('Unknown', inplace=True)
SeaCareerSet['relationship'].fillna('Unknown', inplace=True)
SeaCareerSet['workclass'].fillna('Unknown', inplace=True)
SeaCareerSet['occupation'].fillna('Unknown', inplace=True)
SeaCareerSet['native_country'].fillna('Unknown', inplace=True)

# %%
SeaCareerSet.isnull().sum()
# Out:
# passenger_id      0
# name              0
# sex               0
# age               0
# education         0
# marital_status    0
# relationship      0
# class             0
# fare              0
# sibsp             0
# parch             0
# date_embarked     0
# embarked          2
# workclass         0
# occupation        0
# hours_per_week    0
# capital_gain      0
# capital_loss      0
# native_country    0
# income            0
# survived          0
# dtype: int64

# %% [markdown]
# ## Exo 5

# %%
SeaCareerSet.sort_values(by='hours_per_week', ascending=False)
# Out:
#      passenger_id                                             name     sex  \
# 46             74                      Chronopoulos, Mr. Apostolos    male
# 77            632                      Lundahl, Mr. Johan Svensson    male
# 479           810   Chambers, Mrs. Norman Campbell (Bertha Griggs)  female
# 435           735                     Troupiansky, Mr. Moses Aaron    male
# 517           222                             Bracken, Mr. James H    male
# ..            ...                                              ...     ...
# 713           652                              Doling, Miss. Elsie  female
# 528           524  Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female
# 23            782        Dick, Mrs. Albert Adrian (Vera Gillespie)  female
# 503           722                        Jensen, Mr. Svend Lauritz    male
# 294           253                        Stead, Mr. William Thomas    male
#
# ...

# %%
SeaCareerSet.groupby('occupation')['capital_loss'].mean()
# Out:
# occupation
# ?                     83.025000
# Adm-clerical          39.480519
# Craft-repair         133.500000
# Exec-managerial       59.478873
# Farming-fishing       98.173913
# Handlers-cleaners      0.000000
# Machine-op-inspct     90.000000
# Other-service         72.362319
# Prof-specialty       125.056338
# Protective-serv        0.000000
# Sales                 79.650000
# Tech-support           0.000000
# Transport-moving      67.392857
# Unknown                0.000000
# Name: capital_loss, dtype: float64

# %%
SeaCareerSet.groupby('occupation')['capital_gain'].median()
# Out:
# occupation
# ?                    0.0
# Adm-clerical         0.0
# Craft-repair         0.0
# Exec-managerial      0.0
# Farming-fishing      0.0
# Handlers-cleaners    0.0
# Machine-op-inspct    0.0
# Other-service        0.0
# Prof-specialty       0.0
# Protective-serv      0.0
# Sales                0.0
# Tech-support         0.0
# Transport-moving     0.0
# Unknown              0.0
# Name: capital_gain, dtype: float64

# %%
salary_gr = SeaCareerSet.groupby('income')
min_max = salary_gr.agg({'passenger_id': 'count', 'age': ['min', 'max'], 'hours_per_week': ['min', 'max'], 'capital_gain': ['min', 'max'], 'capital_loss': ['min', 'max']})
min_max
# Out:
#           passenger_id   age       hours_per_week          capital_gain  \
#                  count   min   max            min      max          min
# income
# <=50K              504  17.0  80.0         4.0000  96.0000          0.0
# >50K               110  25.0  74.0         6.0000  84.0000          0.0
# no income          100   1.0  16.0        39.7443  39.7443          0.0
#
#                    capital_loss
#                max          min     max
# income
# <=50K       4865.0          0.0  2603.0
# >50K       99999.0          0.0  2415.0
# no income      0.0          0.0     0.0

# %% [markdown]
# ## Exo 6

# %%
SeaCareerSet['age'].plot(kind='hist', bins=20, color='skyblue', edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
passagers_majeurs = SeaCareerSet[SeaCareerSet['age'] >= 18]

passagers_majeurs['marital_status'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral', 'orange'])
# Out:
# <AxesSubplot:ylabel='marital_status'>

# %% [markdown]
# ## Exo 7

# %%
col_titanic = ['passenger_id', 'survived', 'class', 'fare', 'sibsp', 'parch', 'embarked', 'date_embarked', 'education', 'marital_status', 'relationship']
col_career = ['passenger_id', 'workclass', 'occupation', 'hours_per_week', 'capital_gain', 'capital_loss', 'native_country', 'income']

Titanic = SeaCareerSet[col_titanic]
Career = SeaCareerSet[col_career]

# %%
Career.dropna().copy()
# Out:
#      passenger_id         workclass         occupation  hours_per_week  \
# 1             178         Local-gov     Prof-specialty            65.0
# 2             320           Private       Adm-clerical            45.0
# 4             489  Self-emp-not-inc       Craft-repair            40.0
# 5             848           Private       Craft-repair            40.0
# 6             451           Private     Prof-specialty            40.0
# ..            ...               ...                ...             ...
# 709           689           Private      Other-service            20.0
# 710           158           Private  Machine-op-inspct            40.0
# 711           641           Private  Handlers-cleaners            48.0
# 712           696           Private       Craft-repair            48.0
# 713           652           Private              Sales             8.0
#
#      capital_gain  capital_loss native_country income
# 1             0.0           0.0  United-States  <=50K
# ...

# %%
Career = pd.concat([Career, CareerExtension], ignore_index=True)
Career
# Out:
#      passenger_id         workclass         occupation  hours_per_week  \
# 0           334.0               NaN                NaN             NaN
# 1           178.0         Local-gov     Prof-specialty            65.0
# 2           320.0           Private       Adm-clerical            45.0
# 3           267.0               NaN                NaN             NaN
# 4           489.0  Self-emp-not-inc       Craft-repair            40.0
# ..            ...               ...                ...             ...
# 896           NaN           Private  Handlers-cleaners            40.0
# 897           NaN                 ?                  ?            40.0
# 898           NaN      Self-emp-inc       Craft-repair            50.0
# 899           NaN           Private       Craft-repair            40.0
# 900           NaN           Private  Machine-op-inspct            40.0
#
#      capital_gain  capital_loss native_country     income  education  \
# ...

# %%
Titanic = pd.concat([Titanic, Passenger], ignore_index=True)
Titanic
# Out:
#       passenger_id  survived  class      fare  sibsp  parch embarked  \
# 0              334       0.0    3.0   18.0000    2.0    0.0        S
# 1              178       0.0    1.0   28.7125    0.0    0.0        C
# 2              320       1.0    1.0  134.5000    1.0    1.0        C
# 3              267       0.0    3.0   39.6875    4.0    1.0        S
# 4              489       0.0    3.0    8.0500    0.0    0.0        S
# ...            ...       ...    ...       ...    ...    ...      ...
# 1423           886       NaN    NaN   29.1250    NaN    NaN      NaN
# 1424           887       NaN    NaN   13.0000    NaN    NaN      NaN
# 1425           888       NaN    NaN   30.0000    NaN    NaN      NaN
# 1426           890       NaN    NaN   30.0000    NaN    NaN      NaN
# 1427           891       NaN    NaN    7.7500    NaN    NaN      NaN
#
#          date_embarked     education      marital_status relationship  ticket  \
# ...

# %% [markdown]
# ## Exo 8

# %%
survivants = SeaCareerSet.groupby('sex')['survived'].sum()
total_pass = SeaCareerSet.groupby('sex')['survived'].count()

pourcentage_survivants_par_sexe = (survivants / total_pass) * 100
pourcentage_survivants_par_sexe
# Out:
# sex
# female    75.478927
# male      20.529801
# Name: survived, dtype: float64

# %%
classe_sur = SeaCareerSet.groupby('class')['survived'].sum().idxmax()
classe_sur
# Out:
# 1

# %%
moyenne_tarifs_sur = SeaCareerSet[SeaCareerSet['survived'] == 1]['fare'].mean()
moyenne_tarifs_mor = SeaCareerSet[SeaCareerSet['survived'] == 0]['fare'].mean()
print(moyenne_tarifs_mor)
print(moyenne_tarifs_sur)
# Out:
# 22.965456367924517
# 51.843205172413796

# %%
median_tarif = SeaCareerSet['fare'].median()
SeaCareerSet[SeaCareerSet['fare'] > median_tarif]
# Out:
#      passenger_id                                               name     sex  \
# 0             334                    Vander Planke, Mr. Leo Edmondus    male
# 1             178                         Isham, Miss. Ann Elizabeth  female
# 2             320  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female
# 3             267                          Panula, Mr. Ernesti Arvid    male
# 6             451                              West, Mr. Edwy Arthur    male
# ..            ...                                                ...     ...
# 699           276                  Andrews, Miss. Kornelia Theodosia  female
# 700           633                          Stahelin-Maeglin, Dr. Max    male
# 703           172                               Rice, Master. Arthur    male
# 706           521                              Perreault, Miss. Anne  female
# 713           652                                Doling, Miss. Elsie  female
#
# ...

# %% [markdown]
# ## Exo 9

# %%
SeaCareerSet['title'] = SeaCareerSet['name'].str.extract(r',\s*([^\.]*)\.', expand=False)
distribution_titles = SeaCareerSet['title'].value_counts()
distribution_titles
# Out:
# Mr              398
# Miss            146
# Mrs             108
# Master           36
# Dr                6
# Rev               6
# Col               2
# Major             2
# Mlle              2
# Capt              1
# Sir               1
# Mme               1
# Don               1
# Ms                1
# Jonkheer          1
# the Countess      1
# Lady              1
# Name: title, dtype: int64

# %%
import numpy as np
ages = [
    (SeaCareerSet['age'] <= 2),
    (SeaCareerSet['age'] <= 11),
    (SeaCareerSet['age'] <= 17),
    (SeaCareerSet['age'] >= 18)
]
cat = ['baby', 'kid', 'adolescent', 'adult']
SeaCareerSet['group_age'] = np.select(ages, cat, default='unknown')
SeaCareerSet
# Out:
#      passenger_id                                               name     sex  \
# 0             334                    Vander Planke, Mr. Leo Edmondus    male
# 1             178                         Isham, Miss. Ann Elizabeth  female
# 2             320  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female
# 3             267                          Panula, Mr. Ernesti Arvid    male
# 4             489                      Somerton, Mr. Francis William    male
# ..            ...                                                ...     ...
# 709           689                    Fischer, Mr. Eberhard Thelander    male
# 710           158                                    Corn, Mr. Harry    male
# 711           641                             Jensen, Mr. Hans Peder    male
# 712           696                         Chapman, Mr. Charles Henry    male
# 713           652                                Doling, Miss. Elsie  female
#
# ...

# %%
SeaCareerSet[(SeaCareerSet['age'] < 18) & ((SeaCareerSet['sibsp'] != 0) | (SeaCareerSet['parch'] != 0))]
# Out:
#      passenger_id                                       name     sex   age  \
# 0             334            Vander Planke, Mr. Leo Edmondus    male  16.0
# 3             267                  Panula, Mr. Ernesti Arvid    male  16.0
# 23            782  Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0
# 36            692                         Karun, Miss. Manca  female   4.0
# 39            126               Nicola-Yarred, Master. Elias    male  12.0
# ..            ...                                        ...     ...   ...
# 689           194                 Navratil, Master. Michel M    male   3.0
# 695           789                 Dean, Master. Bertram Vere    male   1.0
# 697           481             Goodwin, Master. Harold Victor    male   9.0
# 703           172                       Rice, Master. Arthur    male   4.0
# 707           173               Johnson, Miss. Eleanor Ileen  female   1.0
#
# ...

# %% [markdown]
# ## Exo 10

# %%
SeaCareerSet['age'].corr(SeaCareerSet['fare'])
# Out:
# 0.09639570663859838

# %%
SeaCareerSet['family_size'] = SeaCareerSet['sibsp'] + SeaCareerSet['parch'] + 1 # +1 pour le passager 
SeaCareerSet['family_size']
# Out:
# 0      3
# 1      1
# 2      3
# 3      6
# 4      1
#       ..
# 709    1
# 710    1
# 711    1
# 712    1
# 713    2
# Name: family_size, Length: 714, dtype: int64

# %%
SeaCareerSet['family_size'].corr(SeaCareerSet['survived'])
# Out:
# 0.04278704955275599

# %% [markdown]
# ## Exo 11

# %%
SeaCareerSet['date_embarked'] = pd.to_datetime(SeaCareerSet['date_embarked'])
SeaCareerSet['date_embarked']
# Out:
# 0     1912-10-04 13:30:00
# 1     1912-10-04 19:50:00
# 2     1912-10-04 19:45:00
# 3     1912-10-04 12:50:00
# 4     1912-10-04 13:40:00
#               ...
# 709   1912-10-04 13:55:00
# 710   1912-10-04 13:55:00
# 711   1912-10-04 12:20:00
# 712   1912-10-04 12:35:00
# 713   1912-10-04 12:55:00
# Name: date_embarked, Length: 714, dtype: datetime64[ns]

# %%
SeaCareerSet['heure_embarked'] = SeaCareerSet['date_embarked'].dt.hour
SeaCareerSet['heure_embarked']
# Out:
# 0      13
# 1      19
# 2      19
# 3      12
# 4      13
#        ..
# 709    13
# 710    13
# 711    12
# 712    12
# 713    12
# Name: heure_embarked, Length: 714, dtype: int64

# %%
SeaCareerSet.pivot_table(values='fare', index=['class', 'sex'], columns=SeaCareerSet['date_embarked'].dt.day, aggfunc='mean')
# Out:
# date_embarked           4
# class sex
# 1     female   107.946275
#       male      71.142781
# 2     female    21.951070
#       male      21.113131
# 3     female    15.875369
#       male      12.162695
